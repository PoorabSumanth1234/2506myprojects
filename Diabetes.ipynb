# %% [markdown]
# <a href="https://colab.research.google.com/github/PoorabSumanth1234/2506myprojects/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from mlxtend.plotting import plot_decision_regions
import missingno as msno
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings ('ignore')
# %matplotlib inline

# %%
import pandas as pd
data=pd.read_csv('/content/diabetes.csv')

# %%
import pandas as pd
data = pd.read_csv('/content/diabetes.csv') # Make sure the path is correct
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# **Exploratory** **data** **analysis**(**EDA**)

# %%
#total number of columns in a dataset
data = pd.DataFrame()
df=pd.DataFrame(data)
num_columns = df.columns

# %%
df=pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
import pandas as pd


data = {
    'Pregnancies': [24, 4, 5],
    'Glucose': [5, 9, 21],
    'BloodPressure': [70, 80, 75],
    'SkinThickness': [20, 25, 22],
    'Insulin': [88, 95, 85],
    'BMI': [30.0, 32.0, 28.0],
    'DiabetesPedigreeFunction': [1,2,3],
    'Age': [30,45,30],
    'Outcome': [5,6,7]
}


df = pd.DataFrame(data)

print(df.describe())
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# count     3.000000   3.000000            3.0       3.000000   3.000000   3.0
# mean     11.000000  11.666667           75.0      22.333333  89.333333  30.0
# std      11.269428   8.326664            5.0       2.516611   5.131601   2.0
# min       4.000000   5.000000           70.0      20.000000  85.000000  28.0
# 25%       4.500000   7.000000           72.5      21.000000  86.500000  29.0
# 50%       5.000000   9.000000           75.0      22.000000  88.000000  30.0
# 75%      14.500000  15.000000           77.5      23.500000  91.500000  31.0
# max      24.000000  21.000000           80.0      25.000000  95.000000  32.0
#
#        DiabetesPedigreeFunction        Age  Outcome
# count                       3.0   3.000000      3.0
# mean                        2.0  35.000000      6.0
# std                         1.0   8.660254      1.0
# min                         1.0  30.000000      5.0
# ...

# %%
df = pd.DataFrame(data)

print(df.describe())
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# count     3.000000   3.000000            3.0       3.000000   3.000000   3.0
# mean     11.000000  11.666667           75.0      22.333333  89.333333  30.0
# std      11.269428   8.326664            5.0       2.516611   5.131601   2.0
# min       4.000000   5.000000           70.0      20.000000  85.000000  28.0
# 25%       4.500000   7.000000           72.5      21.000000  86.500000  29.0
# 50%       5.000000   9.000000           75.0      22.000000  88.000000  30.0
# 75%      14.500000  15.000000           77.5      23.500000  91.500000  31.0
# max      24.000000  21.000000           80.0      25.000000  95.000000  32.0
#
#        DiabetesPedigreeFunction        Age  Outcome
# count                       3.0   3.000000      3.0
# mean                        2.0  35.000000      6.0
# std                         1.0   8.660254      1.0
# min                         1.0  30.000000      5.0
# ...

# %%
df = pd.DataFrame(data)

print(df.describe())
print(df.isnull())
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# count     3.000000   3.000000            3.0       3.000000   3.000000   3.0
# mean     11.000000  11.666667           75.0      22.333333  89.333333  30.0
# std      11.269428   8.326664            5.0       2.516611   5.131601   2.0
# min       4.000000   5.000000           70.0      20.000000  85.000000  28.0
# 25%       4.500000   7.000000           72.5      21.000000  86.500000  29.0
# 50%       5.000000   9.000000           75.0      22.000000  88.000000  30.0
# 75%      14.500000  15.000000           77.5      23.500000  91.500000  31.0
# max      24.000000  21.000000           80.0      25.000000  95.000000  32.0
#
#        DiabetesPedigreeFunction        Age  Outcome
# count                       3.0   3.000000      3.0
# mean                        2.0  35.000000      6.0
# std                         1.0   8.660254      1.0
# min                         1.0  30.000000      5.0
# ...

# %%
  df = pd.DataFrame(data)

print(df.describe())
print(df.isnull().sum())
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# count     3.000000   3.000000            3.0       3.000000   3.000000   3.0
# mean     11.000000  11.666667           75.0      22.333333  89.333333  30.0
# std      11.269428   8.326664            5.0       2.516611   5.131601   2.0
# min       4.000000   5.000000           70.0      20.000000  85.000000  28.0
# 25%       4.500000   7.000000           72.5      21.000000  86.500000  29.0
# 50%       5.000000   9.000000           75.0      22.000000  88.000000  30.0
# 75%      14.500000  15.000000           77.5      23.500000  91.500000  31.0
# max      24.000000  21.000000           80.0      25.000000  95.000000  32.0
#
#        DiabetesPedigreeFunction        Age  Outcome
# count                       3.0   3.000000      3.0
# mean                        2.0  35.000000      6.0
# std                         1.0   8.660254      1.0
# min                         1.0  30.000000      5.0
# ...

# %%
df = pd.DataFrame(data)
import numpy as np

# Create a deep copy of the DataFrame
diabetes_df_copy = df.copy(deep=True)

# Replace 0 with NaN in specific columns
diabetes_df_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = diabetes_df_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.NaN)

# Print the count of missing values in each column
print(diabetes_df_copy.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# #DATA VISUALISATION

# %%
import matplotlib.pyplot as plt
diabetes_df = pd.DataFrame(data)

# Create histograms for each column in the DataFrame
p = diabetes_df.hist(figsize=(20, 20))

# Show the plots
plt.show()

# %%
diabetes_df_copy['Glucose'].fillna(diabetes_df_copy['Glucose'].mean(), inplace=True)
diabetes_df_copy['BloodPressure'].fillna(diabetes_df_copy['BloodPressure'].mean(), inplace=True)
diabetes_df_copy['SkinThickness'].fillna(diabetes_df_copy['SkinThickness'].mean(), inplace=True)
diabetes_df_copy['Insulin'].fillna(diabetes_df_copy['Insulin'].median(), inplace=True)
diabetes_df_copy['BMI'].fillna(diabetes_df_copy['BMI'].median(), inplace=True)

# %%
p=diabetes_df_copy.hist(figsize=(20,20))

# %%
import missingno as msno
p=msno.bar(diabetes_df)

# %%
color_wheel={1: "#0392cf" , 2: "#7bc043"}
colors=diabetes_df["Outcome"].map(lambda x:color_wheel.get(x+1))
print(diabetes_df.Outcome.value_counts())
p=diabetes_df.Outcome.value_counts().plot(kind="bar")
# Out:
# Outcome
# 5    1
# 6    1
# 7    1
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
data = pd.read_csv('/content/diabetes.csv')
diabetes_df = pd.DataFrame(data)

p = scatter_matrix(diabetes_df, figsize=(20, 20))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
p=sns.pairplot(diabetes_df_copy , hue='Outcome')

# %% [markdown]
# ##**Correlation** **between** **all** **features**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,10))
p=sns.heatmap(diabetes_df.corr(), annot=True, cmap='RdYlGn')
plt.show()

# %%
plt.figure(figsize=(12,10))
p=sns.heatmap(diabetes_df_copy.corr(), annot=True, cmap='RdYlGn')
plt.show()

# %%
diabetes_df_copy.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           24        5             70             20       88  30.0
# 1            4        9             80             25       95  32.0
# 2            5       21             75             22       85  28.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         1   30        5
# 1                         2   45        6
# 2                         3   30        7

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()

# Standardizing the features (excluding "Outcome")
X = pd.DataFrame(sc_X.fit_transform(diabetes_df_copy.drop(["Outcome"], axis=1)),
                 columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
                          'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'])

# Displaying the first few rows of the standardized DataFrame
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     1.412821 -0.980581      -1.224745      -1.135550 -0.318223  0.000000
# 1    -0.760750 -0.392232       1.224745       1.297771  1.352447  1.224745
# 2    -0.652071  1.372813       0.000000      -0.162221 -1.034224 -1.224745
#
#    DiabetesPedigreeFunction       Age
# 0                 -1.224745 -0.707107
# 1                  0.000000  1.414214
# 2                  1.224745 -0.707107

# %%
y=diabetes_df_copy.Outcome

# %%
y
# Out:
# 0    5
# 1    6
# 2    7
# Name: Outcome, dtype: int64

# %% [markdown]
# #**Splitting**  **the** **data** **into** **train** **and** **test**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

diabetes_df_copy = diabetes_df.copy()
print(diabetes_df_copy.isnull().sum())


X = diabetes_df_copy.drop("Outcome", axis=1)
y = diabetes_df_copy["Outcome"]


sc_X = StandardScaler()
X_scaled = pd.DataFrame(sc_X.fit_transform(X), columns=X.columns)  # Preserve column names


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33, random_state=42, stratify=y)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Model Building
#
# K-Nearest Neighbor(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
test_scores=[]
train_scores=[]
for i in range(1,15):
  knn=KNeighborsClassifier(i)
  knn.fit(X_train, y_train)
  train_scores.append(knn.score(X_train, y_train))
  test_scores.append(knn.score(X_test, y_test))

# %%
train_scores
# Out:
# [1.0,
#  0.8365758754863813,
#  0.857976653696498,
#  0.8035019455252919,
#  0.8229571984435797,
#  0.791828793774319,
#  0.8093385214007782,
#  0.7898832684824902,
#  0.7996108949416343,
#  0.7723735408560312,
#  0.7859922178988327,
#  0.7821011673151751,
#  0.7898832684824902,
#  0.7821011673151751]

# %%
test_scores
# Out:
# [0.7244094488188977,
#  0.6929133858267716,
#  0.6850393700787402,
#  0.7165354330708661,
#  0.7322834645669292,
#  0.7362204724409449,
#  0.7637795275590551,
#  0.7559055118110236,
#  0.7677165354330708,
#  0.7677165354330708,
#  0.7716535433070866,
#  0.7559055118110236,
#  0.7598425196850394,
#  0.7322834645669292]

# %%
max_train_score = max(train_scores)
test_scores_ind = [i for i, v in enumerate(train_scores) if v == max_train_score]


print("Max train score: {:.2f}% achieved with k values: {}".format(
    max_train_score * 100,
    [i + 1 for i in test_scores_ind]
))
# Out:
# Max train score: 100.00% achieved with k values: [1]

# %%
max_test_score=max(test_scores)
test_scores_ind= [i for i,v in enumerate (test_scores) if v==max_test_score]
print('Max test score {} %n and k={}'. format(max_test_score*100, list(map(lambda x:x+1, test_scores_ind))))
# Out:
# Max test score 77.16535433070865 %n and k=[11]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,5))
plt.plot(range(1, 15), train_scores, marker='*', label='Training Score')
plt.plot(range(1, 15), test_scores, marker='o', label='Testing Score')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(11)
knn.fit(X_train, y_train)
knn.fit(X_test, y_test)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# Assuming X and y are your feature and target variable arrays
value = 20000
width = 20000

# Include ALL features in filler_feature_values
filler_feature_values = {2: value, 3: value, 4: value, 5: value, 6: value, 7: value}

# **CHANGE:** Use integers for the width of the range, not range objects
filler_feature_ranges = {2: width, 3: width, 4: width, 5: width, 6: width, 7: width}

# Assuming X.values and y.values are your feature and target variable arrays
plot_decision_regions(X.values, y.values, clf=knn, legend=2,
                      filler_feature_values=filler_feature_values,
                      filler_feature_ranges=filler_feature_ranges,
                      X_highlight=X_test.values)

plt.title('KNN with diabetes data')
plt.show()

# %% [markdown]
# **CONFUSION** **MATRIX**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
y_pred=knn.predict(X_test)
cnf_matrix=confusion_matrix(y_test, y_pred)
p=sns.heatmap(pd.DataFrame(cnf_matrix), annot=True,cmap='Pastel1', fmt='g')
plt.title('Confusion Matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 19.049999999999997, 'Predicted label')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       165
#            1       0.76      0.57      0.65        89
#
#     accuracy                           0.79       254
#    macro avg       0.78      0.74      0.75       254
# weighted avg       0.78      0.79      0.78       254

# %% [markdown]
# ROC-AUC CURVE

# %%
from sklearn.metrics import roc_curve
y_pred_proba=knn.predict_proba(X_test)[:,1]

fpr, tpr, thresholds=roc_curve(y_test, y_pred_proba)

# %%
import matplotlib.pyplot as plt
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr, tpr,label='Knn')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('Knn(n_neighbors=11) ROC curve')
plt.show()

# %%
y_pred_proba=knn.predict_proba(X_test)[:,1]
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8549880830779707

# %% [markdown]
# **IMPLEMENTING** **GRID** **SEARCH** **CV**

# %%
import pandas as pd
diabetes_df_copy = pd.read_csv('/content/diabetes.csv')  # Load your data here
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
X = diabetes_df_copy.drop("Outcome", axis=1)
y = diabetes_df_copy["Outcome"]
param_grid={'n_neighbors':np.arange(1,50)}
knn=KNeighborsClassifier()
knn_cv=GridSearchCV(knn, param_grid, cv=5)
knn_cv.fit(X,y)

print("Best Score:" + str(knn_cv.best_score_))
print("Best parameters:"+ str(knn_cv.best_params_))
# Out:
# Best Score:0.7578558696205755
# Best parameters:{'n_neighbors': 14}
